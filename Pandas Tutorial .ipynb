# %% [markdown]
# # Ultimate Pandas Tutorial 2023

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Frame Vs Series

# %%
df =  pd.read_csv("https://raw.githubusercontent.com/cajjster/data_files/main/vgsales.csv")

# %%
df
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16286                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16287                     Men in Black II: Alien Escape       GC  2003
# 16288  SCORE International Baja 1000: The Official Game      PS2  2008
# 16289                                        Know How 2       DS  2010
# 16290                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Name"]
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16286                  Woody Woodpecker in Crazy Castle 5
# 16287                       Men in Black II: Alien Escape
# 16288    SCORE International Baja 1000: The Official Game
# 16289                                          Know How 2
# 16290                                    Spirits & Spells
# Name: Name, Length: 16291, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Inspecting Data in Pandas

# %%
df.head()
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii  2006        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16291 non-null  object
#  1   Platform      16291 non-null  object
#  2   Year          16291 non-null  int64
#  3   Genre         16291 non-null  object
#  4   Publisher     16291 non-null  object
#  5   NA_Sales      16291 non-null  float64
#  6   EU_Sales      16291 non-null  float64
#  7   JP_Sales      16291 non-null  float64
#  8   Other_Sales   16291 non-null  float64
#  9   Global Sales  16291 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    2006.405561      0.265647      0.147731      0.078833      0.048426
# std        5.832412      0.822432      0.509303      0.311879      0.190083
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global Sales
# count  16291.000000
# mean       0.540910
# std        1.567345
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.480000
# max       82.740000

# %%
df.describe(include="O")
# Out:
#                                Name Platform   Genre        Publisher
# count                         16291    16291   16291            16291
# unique                        11325       31      12              576
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2131    3251             1339

# %% [markdown]
# ## Selecting Columns in Pandas

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global Sales'],
#       dtype='object')

# %%
df["Genre"]
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16286        Platform
# 16287         Shooter
# 16288          Racing
# 16289          Puzzle
# 16290        Platform
# Name: Genre, Length: 16291, dtype: object

# %%
df[["Genre", "Name", "Platform"]]
# Out:
#               Genre                                              Name Platform
# 0            Sports                                        Wii Sports      Wii
# 1          Platform                                 Super Mario Bros.      NES
# 2            Racing                                    Mario Kart Wii      Wii
# 3            Sports                                 Wii Sports Resort      Wii
# 4      Role-Playing                          Pokemon Red/Pokemon Blue       GB
# ...             ...                                               ...      ...
# 16286      Platform                Woody Woodpecker in Crazy Castle 5      GBA
# 16287       Shooter                     Men in Black II: Alien Escape       GC
# 16288        Racing  SCORE International Baja 1000: The Official Game      PS2
# 16289        Puzzle                                        Know How 2       DS
# 16290      Platform                                  Spirits & Spells      GBA
#
# ...

# %%
df._get_numeric_data()
# Out:
#        Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global Sales
# 0      2006     41.49     29.02      3.77         8.46         82.74
# 1      1985     29.08      3.58      6.81         0.77         40.24
# 2      2008     15.85     12.88      3.79         3.31         35.82
# 3      2009     15.75     11.01      3.28         2.96         33.00
# 4      1996     11.27      8.89     10.22         1.00         31.37
# ...     ...       ...       ...       ...          ...           ...
# 16286  2002      0.01      0.00      0.00         0.00          0.01
# 16287  2003      0.01      0.00      0.00         0.00          0.01
# 16288  2008      0.00      0.00      0.00         0.00          0.01
# 16289  2010      0.00      0.01      0.00         0.00          0.01
# 16290  2003      0.01      0.00      0.00         0.00          0.01
#
# [16291 rows x 6 columns]

# %%
df.select_dtypes(["object", "int"])
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16286                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16287                     Men in Black II: Alien Escape       GC  2003
# 16288  SCORE International Baja 1000: The Official Game      PS2  2008
# 16289                                        Know How 2       DS  2010
# 16290                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher
# 0            Sports    Nintendo
# 1          Platform    Nintendo
# ...

# %%
df[[col for col in df.columns if df[col].nunique()<50]]
# Out:
#       Platform  Year         Genre
# 0          Wii  2006        Sports
# 1          NES  1985      Platform
# 2          Wii  2008        Racing
# 3          Wii  2009        Sports
# 4           GB  1996  Role-Playing
# ...        ...   ...           ...
# 16286      GBA  2002      Platform
# 16287       GC  2003       Shooter
# 16288      PS2  2008        Racing
# 16289       DS  2010        Puzzle
# 16290      GBA  2003      Platform
#
# [16291 rows x 3 columns]

# %% [markdown]
# ## Methods Vs Attributes

# %%
df.shape
# Out:
# (16291, 10)

# %%
df.drop(columns="Name").shape
# Out:
# (16291, 9)

# %%
df.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    2006.405561      0.265647      0.147731      0.078833      0.048426
# std        5.832412      0.822432      0.509303      0.311879      0.190083
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global Sales
# count  16291.000000
# mean       0.540910
# std        1.567345
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.480000
# max       82.740000

# %%
df["Year"].value_counts()
# Out:
# 2009    1431
# 2008    1428
# 2010    1257
# 2007    1201
# 2011    1136
# 2006    1008
# 2005     936
# 2002     829
# 2003     775
# 2004     744
# 2012     655
# 2015     614
# 2014     580
# 2013     546
# 2001     482
# 1998     379
# 2000     349
# 2016     342
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# 2017       3
# 2020       1
# Name: Year, dtype: int64

# %% [markdown]
# ## Intuition or Common Sense in Pandas

# %%
year = df["Year"]

# %%
type(year)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
year.shape
# Out:
# (16291,)

# %%
df["Platform"].value_counts()
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
year.sort_values()
# Out:
# 257      1980
# 6211     1980
# 1948     1980
# 5282     1980
# 1746     1980
#          ...
# 5205     2016
# 14136    2017
# 16135    2017
# 15944    2017
# 5860     2020
# Name: Year, Length: 16291, dtype: int64

# %%
df.sort_values(by="Genre")
# Out:
#                                                     Name Platform  Year  \
# 8145   Ringling Bros. and Barnum & Bailey: Circus Fri...       DS  2009
# 4030                       Madagascar: Operation Penguin      GBA  2005
# 11414  Dangerous Ji-San to 1000-nin no Otomodachi Yok...      3DS  2012
# 11412                                           Terraria      3DS  2016
# 11410                                      Auto Destruct       PS  1998
# ...                                                  ...      ...   ...
# 15584                                       Elven Legacy       PC  2009
# 11780                                 Hearts of Iron III       PC  2009
# 5191                                    Battalion Wars 2      Wii  2007
# 11830                 Real Time Conflict: Shogun Empires       DS  2005
# 1822                                            Pikmin 3     WiiU  2013
#
#           Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Method Changing in Pandas

# %%
df["Genre"].value_counts().sort_index()
# Out:
# Action          3251
# Adventure       1274
# Fighting         836
# Misc            1686
# Platform         875
# Puzzle           570
# Racing          1225
# Role-Playing    1470
# Shooter         1282
# Simulation       848
# Sports          2304
# Strategy         670
# Name: Genre, dtype: int64

# %%
df["Genre"].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["Genre"].sort_index().value_counts()
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
df["Genre"].sort_index().value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## loc[] and iloc[]

# %%
# integer lock 
df.iloc[4]
# Out:
# Name            Pokemon Red/Pokemon Blue
# Platform                              GB
# Year                                1996
# Genre                       Role-Playing
# Publisher                       Nintendo
# NA_Sales                           11.27
# EU_Sales                            8.89
# JP_Sales                           10.22
# Other_Sales                          1.0
# Global Sales                       31.37
# Name: 4, dtype: object

# %%
df.iloc[:5]
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii  2006        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
df.loc[:5]
# Out:
#                        Name Platform  Year         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii  2006        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo     11.27
# 5                    Tetris       GB  1989        Puzzle  Nintendo     23.20
#
#    EU_Sales  JP_Sales  Other_Sales  Global Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37
# 5      2.26      4.22         0.58         30.26

# %%
# [start:stop:step]
df.iloc[1:10:2]
# Out:
#                 Name Platform  Year     Genre Publisher  NA_Sales  EU_Sales  \
# 1  Super Mario Bros.      NES  1985  Platform  Nintendo     29.08      3.58
# 3  Wii Sports Resort      Wii  2009    Sports  Nintendo     15.75     11.01
# 5             Tetris       GB  1989    Puzzle  Nintendo     23.20      2.26
# 7           Wii Play      Wii  2006      Misc  Nintendo     14.03      9.20
# 9          Duck Hunt      NES  1984   Shooter  Nintendo     26.93      0.63
#
#    JP_Sales  Other_Sales  Global Sales
# 1      6.81         0.77         40.24
# 3      3.28         2.96         33.00
# 5      4.22         0.58         30.26
# 7      2.93         2.85         29.02
# 9      0.28         0.47         28.31

# %%
df.iloc[:]
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16286                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16287                     Men in Black II: Alien Escape       GC  2003
# 16288  SCORE International Baja 1000: The Official Game      PS2  2008
# 16289                                        Know How 2       DS  2010
# 16290                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df.iloc[:-1]
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16285                                          Plushees       DS  2008
# 16286                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16287                     Men in Black II: Alien Escape       GC  2003
# 16288  SCORE International Baja 1000: The Official Game      PS2  2008
# 16289                                        Know How 2       DS  2010
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
# [start,stop,step, start:stop:step]
df.iloc[:, 2:5]
# Out:
#        Year         Genre   Publisher
# 0      2006        Sports    Nintendo
# 1      1985      Platform    Nintendo
# 2      2008        Racing    Nintendo
# 3      2009        Sports    Nintendo
# 4      1996  Role-Playing    Nintendo
# ...     ...           ...         ...
# 16286  2002      Platform       Kemco
# 16287  2003       Shooter  Infogrames
# 16288  2008        Racing  Activision
# 16289  2010        Puzzle    7G//AMES
# 16290  2003      Platform     Wanadoo
#
# [16291 rows x 3 columns]

# %%
df.iloc[3:10, 5:-1]
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 3     15.75     11.01      3.28         2.96
# 4     11.27      8.89     10.22         1.00
# 5     23.20      2.26      4.22         0.58
# 6     11.38      9.23      6.50         2.90
# 7     14.03      9.20      2.93         2.85
# 8     14.59      7.06      4.70         2.26
# 9     26.93      0.63      0.28         0.47

# %%
df.loc[:1000, "Publisher"]
# Out:
# 0                           Nintendo
# 1                           Nintendo
# 2                           Nintendo
# 3                           Nintendo
# 4                           Nintendo
#                     ...
# 996     Konami Digital Entertainment
# 997           Microsoft Game Studios
# 998                         Nintendo
# 999                           Capcom
# 1000                        Nintendo
# Name: Publisher, Length: 1001, dtype: object

# %%
df.loc[:1000, ["Publisher", "Platform", "NA_Sales"]]
# Out:
#                          Publisher Platform  NA_Sales
# 0                         Nintendo      Wii     41.49
# 1                         Nintendo      NES     29.08
# 2                         Nintendo      Wii     15.85
# 3                         Nintendo      Wii     15.75
# 4                         Nintendo       GB     11.27
# ...                            ...      ...       ...
# 996   Konami Digital Entertainment      PS2      0.06
# 997         Microsoft Game Studios     X360      1.00
# 998                       Nintendo      NES      0.70
# 999                         Capcom     SNES      0.94
# 1000                      Nintendo      NES      0.79
#
# [1001 rows x 3 columns]

# %%
df.loc[100, "NA_Sales"]
# Out:
# 3.83

# %%
df.loc[100, "NA_Sales"] = 3.84

# %%
df.loc[100, "NA_Sales"]
# Out:
# 3.84

# %% [markdown]
# ## Filter with Conditional logic using loc[]

# %%
for i in df[["Name", "Platform", "Year", "Genre", "Publisher"]]:
    print(i.upper())
    print(df[i].unique())
    print()
# Out:
# NAME
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ... 'Plushees'
#  'Woody Woodpecker in Crazy Castle 5' 'Know How 2']
#
# PLATFORM
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
# YEAR
# [2006 1985 2008 2009 1996 1989 1984 2005 1999 2007 2010 2013 2004 1990
#  1988 2002 2001 2011 1998 2015 2012 2014 1992 1997 1993 1994 1982 2003
#  1986 2000 1995 2016 1991 1981 1987 1980 1983 2020 2017]
#
# GENRE
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
#
# PUBLISHER
# ['Nintendo' 'Microsoft Game Studios' 'Take-Two Interactive'
#  'Sony Computer Entertainment' 'Activision' 'Ubisoft' 'Bethesda Softworks'
#  'Electronic Arts' 'Sega' 'SquareSoft' 'Atari' '505 Games' 'Capcom'
#  'GT Interactive' 'Konami Digital Entertainment'
# ...

# %%
wii = df["Platform"] == "Wii"

# %%
wii
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 16286    False
# 16287    False
# 16288    False
# 16289    False
# 16290    False
# Name: Platform, Length: 16291, dtype: bool

# %%
df.loc[wii]
# Out:
#                                                     Name Platform  Year  \
# 0                                             Wii Sports      Wii  2006
# 2                                         Mario Kart Wii      Wii  2008
# 3                                      Wii Sports Resort      Wii  2009
# 7                                               Wii Play      Wii  2006
# 8                              New Super Mario Bros. Wii      Wii  2009
# ...                                                  ...      ...   ...
# 16212                       Teenage Mutant Ninja Turtles      Wii  2007
# 16246           Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii  2007
# 16266                                Mini Desktop Racing      Wii  2007
# 16267  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii  2008
# 16274                                          Fit & Fun      Wii  2011
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.loc[df["Platform"] == "PS2"]
# Out:
#                                                    Name Platform  Year  \
# 17                        Grand Theft Auto: San Andreas      PS2  2004
# 24                          Grand Theft Auto: Vice City      PS2  2002
# 28                               Gran Turismo 3: A-Spec      PS2  2001
# 38                                 Grand Theft Auto III      PS2  2001
# 47                                       Gran Turismo 4      PS2  2004
# ...                                                 ...      ...   ...
# 16252      Sugar + Spice! Anoko no Suteki na Nanimokamo      PS2  2008
# 16254                                    Kanokon: Esuii      PS2  2008
# 16265                  Scarlett: Nichijou no Kyoukaisen      PS2  2008
# 16273                                         Real Rode      PS2  2008
# 16288  SCORE International Baja 1000: The Official Game      PS2  2008
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.loc[df["JP_Sales"] > df["EU_Sales"], "Name"]
# Out:
# 1                                        Super Mario Bros.
# 4                                 Pokemon Red/Pokemon Blue
# 5                                                   Tetris
# 12                             Pokemon Gold/Pokemon Silver
# 17                           Grand Theft Auto: San Andreas
#                                ...
# 16268                                Neo Angelique Special
# 16273                                            Real Rode
# 16280                             Mezase!! Tsuri Master DS
# 16282    Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...
# 16283    Eiyuu Densetsu: Sora no Kiseki Material Collec...
# Name: Name, Length: 4554, dtype: object

# %%
df.loc[(df["Platform"]=="Wii")& (df["Genre"]=="Role-Playing")].sort_values(by="Global Sales", ascending=False)
# Out:
#                                                     Name Platform  Year  \
# 709                                   Monster Hunter Tri      Wii  2009
# 1127                           Pokemon Battle Revolution      Wii  2006
# 2083                                Xenoblade Chronicles      Wii  2010
# 2126                                      Dragon Quest X      Wii  2012
# 2818   Dragon Quest Swords: The Masked Queen and the ...      Wii  2007
# 2934                                      The Last Story      Wii  2011
# 3234                           Muramasa: The Demon Blade      Wii  2009
# 3698           Tales of Symphonia: Dawn of the New World      Wii  2008
# 4110   Dragon Quest 25 Shuunen Kinin: Famicom & Super...      Wii  2011
# 4679                           Marvel: Ultimate Alliance      Wii  2006
# 4826                              Rune Factory: Frontier      Wii  2008
# 4915          Fragile Dreams: Farewell Ruins of the Moon      Wii  2009
# ...

# %%
rpg = df["Genre"] == "Role-Playing"

# %%
df.loc[wii & rpg]
# Out:
#                                                     Name Platform  Year  \
# 709                                   Monster Hunter Tri      Wii  2009
# 1127                           Pokemon Battle Revolution      Wii  2006
# 2083                                Xenoblade Chronicles      Wii  2010
# 2126                                      Dragon Quest X      Wii  2012
# 2818   Dragon Quest Swords: The Masked Queen and the ...      Wii  2007
# 2934                                      The Last Story      Wii  2011
# 3234                           Muramasa: The Demon Blade      Wii  2009
# 3698           Tales of Symphonia: Dawn of the New World      Wii  2008
# 4110   Dragon Quest 25 Shuunen Kinin: Famicom & Super...      Wii  2011
# 4679                           Marvel: Ultimate Alliance      Wii  2006
# 4826                              Rune Factory: Frontier      Wii  2008
# 4915          Fragile Dreams: Farewell Ruins of the Moon      Wii  2009
# ...

# %%
# Filter in Or Condition 
# Or Needs at least one condition to be true 

action = df["Genre"] == "Action"
shooter = df["Genre"] == "Shooter"

df.loc[action | shooter]
# | this is use for or
# Out:
#                                                     Name Platform  Year  \
# 9                                              Duck Hunt      NES  1984
# 16                                    Grand Theft Auto V      PS3  2013
# 17                         Grand Theft Auto: San Andreas      PS2  2004
# 23                                    Grand Theft Auto V     X360  2013
# 24                           Grand Theft Auto: Vice City      PS2  2002
# ...                                                  ...      ...   ...
# 16275                                    Planet Monsters      GBA  2001
# 16276                                     Carmageddon 64      N64  1999
# 16278                                             Breach       PC  2011
# 16282  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016
# 16287                      Men in Black II: Alien Escape       GC  2003
#
#          Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Filter with both Or and AND condition 

since_2010 = df["Year"] >= 2010

df.loc[(since_2010) & (action | shooter)]
# Out:
#                                                     Name Platform  Year  \
# 16                                    Grand Theft Auto V      PS3  2013
# 23                                    Grand Theft Auto V     X360  2013
# 29                        Call of Duty: Modern Warfare 3     X360  2011
# 31                               Call of Duty: Black Ops     X360  2010
# 33                             Call of Duty: Black Ops 3      PS4  2015
# ...                                                  ...      ...   ...
# 16244  God Eater Off Shot: Tachibana Sakuya-hen Twin ...      PS4  2016
# 16260  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS  2014
# 16262                                 Resident Evil 4 HD     XOne  2016
# 16278                                             Breach       PC  2011
# 16282  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016
#
#          Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.loc[since_2010 & action | shooter]
# Out:
#                                                     Name Platform  Year  \
# 9                                              Duck Hunt      NES  1984
# 16                                    Grand Theft Auto V      PS3  2013
# 23                                    Grand Theft Auto V     X360  2013
# 29                        Call of Duty: Modern Warfare 3     X360  2011
# 31                               Call of Duty: Black Ops     X360  2010
# ...                                                  ...      ...   ...
# 16262                                 Resident Evil 4 HD     XOne  2016
# 16270                                          Damnation       PC  2009
# 16278                                             Breach       PC  2011
# 16282  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016
# 16287                      Men in Black II: Alien Escape       GC  2003
#
#          Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# isin()

top_3_publishers = df.Publisher.isin(["Electronic Arts", "Activision", "Namco Bandai Games"])

# %%
df.loc[top_3_publishers]
# Out:
#                                                     Name Platform  Year  \
# 29                        Call of Duty: Modern Warfare 3     X360  2011
# 31                               Call of Duty: Black Ops     X360  2010
# 33                             Call of Duty: Black Ops 3      PS4  2015
# 34                            Call of Duty: Black Ops II      PS3  2012
# 35                            Call of Duty: Black Ops II     X360  2012
# ...                                                  ...      ...   ...
# 16234                          Spore Galactic Adventures       PC  2009
# 16244  God Eater Off Shot: Tachibana Sakuya-hen Twin ...      PS4  2016
# 16247                                  Psychic Detective       PS  1995
# 16260  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS  2014
# 16288   SCORE International Baja 1000: The Official Game      PS2  2008
#
#            Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
genres = df.Genre.isin(["Sports", "Action", "Shooter"])
sales_2M = df["Global Sales"] >= 2

# %%
df.loc[genres & top_3_publishers & sales_2M]
# Out:
#                                Name Platform  Year    Genre        Publisher  \
# 29   Call of Duty: Modern Warfare 3     X360  2011  Shooter       Activision
# 31          Call of Duty: Black Ops     X360  2010  Shooter       Activision
# 33        Call of Duty: Black Ops 3      PS4  2015  Shooter       Activision
# 34       Call of Duty: Black Ops II      PS3  2012  Shooter       Activision
# 35       Call of Duty: Black Ops II     X360  2012  Shooter       Activision
# ..                              ...      ...   ...      ...              ...
# 826                   Madden NFL 15      PS4  2014   Sports  Electronic Arts
# 829                   NBA Live 2004      PS2  2003   Sports  Electronic Arts
# 830                      Dead Space      PS3  2008   Action  Electronic Arts
# 831                  Call of Duty 2     X360  2005  Shooter       Activision
# 832                   Madden NFL 15     X360  2014   Sports  Electronic Arts
#
# ...

# %%
# between allows us ti spesify a range 
between_2M_10M = df["Global Sales"].between(2, 10)

y_90s = df["Year"].between(1990, 1999)
y_00s = df["Year"].between(1990, 2009)
y_10s  = df["Year"].between(1990, 2019)

# %%
df.loc[between_2M_10M & y_90s, "Genre"].value_counts(normalize=True)
# Out:
# Platform        0.198413
# Action          0.166667
# Racing          0.119048
# Role-Playing    0.095238
# Fighting        0.095238
# Shooter         0.063492
# Strategy        0.063492
# Misc            0.063492
# Sports          0.055556
# Simulation      0.031746
# Adventure       0.031746
# Puzzle          0.015873
# Name: Genre, dtype: float64

# %%
df.loc[between_2M_10M & y_00s, "Genre"].value_counts(normalize=True)
# Out:
# Action          0.195652
# Platform        0.114625
# Sports          0.114625
# Role-Playing    0.108696
# Shooter         0.094862
# Misc            0.094862
# Racing          0.092885
# Fighting        0.071146
# Simulation      0.047431
# Puzzle          0.027668
# Strategy        0.021739
# Adventure       0.015810
# Name: Genre, dtype: float64

# %%
df.loc[between_2M_10M & y_10s, "Genre"].value_counts(normalize=True)
# Out:
# Action          0.214190
# Sports          0.139224
# Shooter         0.125837
# Role-Playing    0.112450
# Platform        0.093708
# Misc            0.091031
# Racing          0.076305
# Fighting        0.054886
# Simulation      0.041499
# Puzzle          0.020080
# Strategy        0.016064
# Adventure       0.014726
# Name: Genre, dtype: float64

# %%
df.loc[~df["Genre"].isin(["Puzzle", "Strategy", "Advanture"]) & -y_10s]
# Out:
#                                       Name Platform  Year       Genre  \
# 1                        Super Mario Bros.      NES  1985    Platform
# 9                                Duck Hunt      NES  1984     Shooter
# 21                        Super Mario Land       GB  1989    Platform
# 22                     Super Mario Bros. 3      NES  1988    Platform
# 96                     Super Mario Bros. 2      NES  1988    Platform
# ...                                    ...      ...   ...         ...
# 11510                       Super Football     2600  1987      Sports
# 11543                       Super Baseball     2600  1987      Sports
# 14082                            Alter Ego       PC  1985  Simulation
# 14252                              SimCity       PC  1988  Simulation
# 15582  Strongest Tokyo University Shogi DS       DS  1985      Action
#
#         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global Sales
# ...

# %%
#Let's find out which racing games had the highest sales in EU compared to the NA, JP, Other Sales
# between the years 2000-2009


racing = df["Genre"] == "Racing"
highest_EU = (df["EU_Sales"] > df["JP_Sales"]) & (df["EU_Sales"] > df["NA_Sales"]) & (df["EU_Sales"] > df["Other_Sales"]) 
y_00 = df["Year"].between(2000, 2009)

# %%
df.loc[racing & highest_EU & y_00, ["Name", "EU_Sales"]].sort_values(by="EU_Sales", ascending=False).head().set_index("Name")
# Out:
#                               EU_Sales
# Name
# Need for Speed Underground 2      3.02
# The Simpsons: Hit & Run           2.19
# Gran Turismo 5 Prologue           1.83
# MotorStorm                        1.61
# Gran Turismo (PSP)                1.59

# %% [markdown]
# # Most Useful Method for Data Analysis

# %%
#query()

df.query("NA_Sales < JP_Sales")
# Out:
#                                                     Name Platform  Year  \
# 26                           Pokemon Black/Pokemon White       DS  2010
# 27           Brain Age 2: More Training in Minutes a Day       DS  2005
# 41                           Animal Crossing: Wild World       DS  2005
# 66                                     Final Fantasy VII       PS  1997
# 73                             Animal Crossing: New Leaf      3DS  2012
# ...                                                  ...      ...   ...
# 16268                              Neo Angelique Special      PSP  2008
# 16273                                          Real Rode      PS2  2008
# 16280                           Mezase!! Tsuri Master DS       DS  2009
# 16282  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016
# 16283  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP  2007
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df.query("Publisher == 'Ubisoft' and Year > 2014")
# Out:
#                                               Name Platform  Year       Genre  \
# 350                      Tom Clancy's The Division      PS4  2016     Shooter
# 407                     Assassin's Creed Syndicate      PS4  2015      Action
# 749                Tom Clancy's Rainbow Six: Siege      PS4  2015     Shooter
# 761                                Far Cry: Primal      PS4  2016      Action
# 835                      Tom Clancy's The Division     XOne  2016     Shooter
# 1515               Tom Clancy's Rainbow Six: Siege     XOne  2015     Shooter
# 1527                    Assassin's Creed Syndicate     XOne  2015      Action
# 1651                               Just Dance 2016      Wii  2015        Misc
# 2400                               Far Cry: Primal     XOne  2016      Action
# 3391                               Just Dance 2016     WiiU  2015        Misc
# 5026                     Tom Clancy's The Division       PC  2016     Shooter
# ...

# %%
ps3 = df.query("Platform == 'PS3'")

# %%
ps3
# Out:
#                                                     Name Platform  Year  \
# 16                                    Grand Theft Auto V      PS3  2013
# 34                            Call of Duty: Black Ops II      PS3  2012
# 37                        Call of Duty: Modern Warfare 3      PS3  2011
# 40                               Call of Duty: Black Ops      PS3  2010
# 54                                        Gran Turismo 5      PS3  2010
# ...                                                  ...      ...   ...
# 16147                        Hyperdimension Neptunia mk2      PS3  2011
# 16148  Shin Koihime Musou: Otome Taisen * Sangokushi ...      PS3  2014
# 16177                                Muv-Luv Alternative      PS3  2012
# 16216                           Akatsuki no Goei Trinity      PS3  2012
# 16236                                    Battle Fantasia      PS3  2008
#
#             Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Unique and nunique 

df.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df.nunique()
# Out:
# Name            11325
# Platform           31
# Year               39
# Genre              12
# Publisher         576
# NA_Sales          408
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global Sales      621
# dtype: int64

# %%
df["Year"].nunique()
# Out:
# 39

# %%
for i in df.select_dtypes("object"):
    print(df[i].unique())
# Out:
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ... 'Plushees'
#  'Woody Woodpecker in Crazy Castle 5' 'Know How 2']
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
# ['Nintendo' 'Microsoft Game Studios' 'Take-Two Interactive'
#  'Sony Computer Entertainment' 'Activision' 'Ubisoft' 'Bethesda Softworks'
#  'Electronic Arts' 'Sega' 'SquareSoft' 'Atari' '505 Games' 'Capcom'
#  'GT Interactive' 'Konami Digital Entertainment'
#  'Sony Computer Entertainment Europe' 'Square Enix' 'LucasArts'
#  'Virgin Interactive' 'Warner Bros. Interactive Entertainment'
#  'Universal Interactive' 'Eidos Interactive' 'RedOctane' 'Vivendi Games'
#  'Enix Corporation' 'Namco Bandai Games' 'Palcom' 'Hasbro Interactive'
# ...

# %%
 # rename and set index 
    
ps3.reset_index(drop=True, inplace=True)

# %%
ps3
# Out:
#                                                    Name Platform  Year  \
# 0                                    Grand Theft Auto V      PS3  2013
# 1                            Call of Duty: Black Ops II      PS3  2012
# 2                        Call of Duty: Modern Warfare 3      PS3  2011
# 3                               Call of Duty: Black Ops      PS3  2010
# 4                                        Gran Turismo 5      PS3  2010
# ...                                                 ...      ...   ...
# 1299                        Hyperdimension Neptunia mk2      PS3  2011
# 1300  Shin Koihime Musou: Otome Taisen * Sangokushi ...      PS3  2014
# 1301                                Muv-Luv Alternative      PS3  2012
# 1302                           Akatsuki no Goei Trinity      PS3  2012
# 1303                                    Battle Fantasia      PS3  2008
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
ps3.set_index("Name", inplace=True)

# %%
ps3.rename({"EU_Sales": "Europe", "NA_Sales":"North America"}, axis=1 )
# Out:
#                                                    Platform  Year       Genre  \
# Name
# Grand Theft Auto V                                      PS3  2013      Action
# Call of Duty: Black Ops II                              PS3  2012     Shooter
# Call of Duty: Modern Warfare 3                          PS3  2011     Shooter
# Call of Duty: Black Ops                                 PS3  2010     Shooter
# Gran Turismo 5                                          PS3  2010      Racing
# ...                                                     ...   ...         ...
# Hyperdimension Neptunia mk2                             PS3  2011      Action
# Shin Koihime Musou: Otome Taisen * Sangokushi Engi      PS3  2014   Adventure
# Muv-Luv Alternative                                     PS3  2012  Simulation
# Akatsuki no Goei Trinity                                PS3  2012   Adventure
# Battle Fantasia                                         PS3  2008    Fighting
#
# ...

# %%
ps3.rename({"Call of Duty: Black Ops II": "COD Black Ops 2"})
# Out:
#                                                    Platform  Year       Genre  \
# Name
# Grand Theft Auto V                                      PS3  2013      Action
# COD Black Ops 2                                         PS3  2012     Shooter
# Call of Duty: Modern Warfare 3                          PS3  2011     Shooter
# Call of Duty: Black Ops                                 PS3  2010     Shooter
# Gran Turismo 5                                          PS3  2010      Racing
# ...                                                     ...   ...         ...
# Hyperdimension Neptunia mk2                             PS3  2011      Action
# Shin Koihime Musou: Otome Taisen * Sangokushi Engi      PS3  2014   Adventure
# Muv-Luv Alternative                                     PS3  2012  Simulation
# Akatsuki no Goei Trinity                                PS3  2012   Adventure
# Battle Fantasia                                         PS3  2008    Fighting
#
# ...

# %%
 # nlargest and nsmallest

# %%
ps3.nlargest(n=10, columns ="NA_Sales").loc[:, "NA_Sales"].plot.bar()
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 20))

ps3.nlargest(n=10, columns="NA_Sales").loc[:, "NA_Sales"].plot.bar(ax=ax[0][0])
ax[0][0].set_title("North America")
ps3.nlargest(n=10, columns="JP_Sales").loc[:, "JP_Sales"].plot.bar(ax=ax[0][1])
ax[0][1].set_title("Japan")
ps3.nlargest(n=10, columns="EU_Sales").loc[:, "EU_Sales"].plot.bar(ax=ax[1][0])
ax[1][0].set_title("Europe")
ps3.nlargest(n=10, columns="Other_Sales").loc[:, "Other_Sales"].plot.bar(ax=ax[1][1])
ax[1][1].set_title("Other")

fig.suptitle("Most sold PS3 games by continent", fontsize=20)
fig.tight_layout()

# %%
fig.savefig("ps3_Sales.png")

# %%
ps3.nsmallest(n=5, columns="Global Sales")
# Out:
#                                                    Platform  Year  \
# Name
# Nobunaga no Yabou Online: Houou no Shou                 PS3  2012
# Utawarerumono: Futari no Hakuoro                        PS3  2016
# Pro Angler Moves                                        PS3  2012
# The Legend of Heroes: Trails in the Sky Third C...      PS3  2013
# Higurashi no Naku Koro ni Iki                           PS3  2015
#
#                                                            Genre  \
# Name
# Nobunaga no Yabou Online: Houou no Shou                 Strategy
# Utawarerumono: Futari no Hakuoro                            Misc
# Pro Angler Moves                                          Sports
# The Legend of Heroes: Trails in the Sky Third C...  Role-Playing
# Higurashi no Naku Koro ni Iki                             Action
#
#                                                                      Publisher  \
# Name
# ...

# %%
# Valie_counts()
top_100 = ps3.nlargest(n=100, columns = "Global Sales")

# %%
top_100["Genre"].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,8))

top_100["Genre"].value_counts().plot.barh(ax=ax[0])
top_100["Publisher"].value_counts().plot.barh(ax=ax[1])

plt.tight_layout()

# %%
# sort_values()

ps3.sort_values(by ="Year", ascending= True)
# Out:
#                                                    Platform  Year       Genre  \
# Name
# Blazing Angels: Squadrons of WWII                       PS3  2006  Simulation
# NBA 2K7                                                 PS3  2006      Sports
# Genji: Days of the Blade                                PS3  2006      Action
# Resistance: Fall of Man                                 PS3  2006     Shooter
# Tiger Woods PGA Tour 07                                 PS3  2006      Sports
# ...                                                     ...   ...         ...
# Utawarerumono: Futari no Hakuoro                        PS3  2016        Misc
# Sengoku Basara: Sanada Yukimura-Den                     PS3  2016      Action
# Nobunaga's Ambition: Sphere of Influence - Seng...      PS3  2016        Misc
# FIFA 17                                                 PS3  2016      Sports
# UEFA Euro 2016                                          PS3  2016      Sports
#
# ...

# %%
ps3.sort_values(by=["Year", "Global Sales"], ascending= [True, False])
# Out:
#                                                    Platform  Year      Genre  \
# Name
# Resistance: Fall of Man                                 PS3  2006    Shooter
# MotorStorm                                              PS3  2006     Racing
# Fight Night Round 3                                     PS3  2006   Fighting
# Call of Duty 3                                          PS3  2006    Shooter
# Ridge Racer 7                                           PS3  2006     Racing
# ...                                                     ...   ...        ...
# TV Anime Idolm@ster: Cinderella Girls G4U! Pack...      PS3  2016       Misc
# Call of Duty: Modern Warfare Trilogy                    PS3  2016    Shooter
# Toukiden 2                                              PS3  2016     Action
# Utawarerumono: Futari no Hakuoro                        PS3  2016       Misc
# Batman: A Telltale Game Series                          PS3  2016  Adventure
#
# ...

# %%
#aggfuncs + agg() & cumsum()

print("Min Year", df.Year.min())
print("Max Year", df.Year.max())
print("Mean Year", df.Year.mean())
print("Std Year", df.Year.std())
print("Median Year", df.Year.median())
print("Count number of rows in Year", df.Year.count())
print("Sum of EU_Sales: ", df.EU_Sales.sum())
print("Mode Name", df.Name.mode()[0])
# Out:
# Min Year 1980
# Max Year 2020
# Mean Year 2006.4055613528942
# Std Year 5.8324122195220385
# Median Year 2007.0
# Count number of rows in Year 16291
# Sum of EU_Sales:  2406.69
# Mode Name Need for Speed: Most Wanted

# %%
df.EU_Sales.cumsum()
# Out:
# 0          29.02
# 1          32.60
# 2          45.48
# 3          56.49
# 4          65.38
#           ...
# 16286    2406.68
# 16287    2406.68
# 16288    2406.68
# 16289    2406.69
# 16290    2406.69
# Name: EU_Sales, Length: 16291, dtype: float64

# %%
xbox_sales = df.loc[df.Platform == "XB", ["NA_Sales", "Year"]].groupby("Year")["NA_Sales"].sum()

# %%
xbox_sales.cumsum()
# Out:
# Year
# 2000      0.74
# 2001     17.35
# 2002     51.40
# 2003     90.74
# 2004    139.21
# 2005    174.05
# 2006    181.52
# 2007    181.93
# 2008    182.06
# Name: NA_Sales, dtype: float64

# %%
xbox_sales.cumsum().plot.area()
# Out:
# <AxesSubplot:xlabel='Year'>
